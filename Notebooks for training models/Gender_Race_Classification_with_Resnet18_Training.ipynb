# %% [markdown]
# # 01_Library

# %% [markdown]
# ## install

# %%
! pip install -q torchmetrics

# %% [markdown]
# ## import

# %%
import os
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2 as cv
import PIL
from PIL import Image

import sklearn
from sklearn.model_selection import train_test_split

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
from torch import optim
from torch.nn import functional as F

import torchvision
import torchvision.transforms as transforms
import torchvision.models as models

import tqdm
import torchmetrics as tm

# %%
# !python --version
# Out:
# Python 3.11.11

# %%
for lib in [np, pd, cv, PIL, sklearn, torch, torchvision, tqdm, tm]:
  print(lib.__name__, '-->', lib.__version__)
# Out:
# numpy --> 1.26.4
# pandas --> 2.2.2
# cv2 --> 4.11.0
# PIL --> 11.1.0
# sklearn --> 1.6.1
# torch --> 2.5.1+cu124
# torchvision --> 0.20.1+cu124
# tqdm --> 4.67.1
# torchmetrics --> 1.6.2

# %% [markdown]
# ------------------

# %% [markdown]
# # 02_Utils

# %% [markdown]
# ## device

# %%
device= 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ## system

# %%
system= "colab"

if system== "local":
    drive_path= r"./"
    dataset_folder= './UTKFace/'
elif system== "colab":
    drive_path= r"/content/drive/MyDrive/Catalist/0_age estimation/"
    dataset_folder= '/content/UTKFace/'

# %% [markdown]
# ## avragemeter

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# ## number of parameter fn

# %%
def num_trainable_params(model):
  nums= sum(p.numel() for p in model.parameters() if p.requires_grad)/1e6
  return nums

# %% [markdown]
# ## drive mount

# %%
if system== "colab":
    from google.colab import drive
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ----------------

# %% [markdown]
# # 03_Data

# %%
if system== "colab":
    data_path= os.path.join(drive_path,'UTKFace.tar.gz')
    ! tar -xzf "{data_path}" -C '/content/'

# %% [markdown]
# --------

# %% [markdown]
# # 04_EDA (Exploratory Data Analysis)

# %% [markdown]
# ## show sample of images

# %%
def show_random_samples(num_samples= 9):
    image_files= os.listdir(dataset_folder)
    selected_image_files= random.sample(image_files, num_samples)

    plt.figure(figsize= (10, 10))
    for idx, image_file in enumerate(selected_image_files, 1):
        image_path= os.path.join(dataset_folder, image_file)
        age, gender, ethnicity= image_file.split('_')[:3]

        image = Image.open(image_path)

        gender= 'Male' if int(gender)== 0 else 'Female'
        ethnicity= ['White', 'Black', 'Asian', 'Indian', 'Others'][int(ethnicity)]

        plt.subplot(3, 3, idx)
        plt.imshow(image)
        plt.title(f"Age: {age}\nGender: {gender}\nEthnicity: {ethnicity}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

show_random_samples()

# %% [markdown]
# ## create csv file contain list of images

# %%
image_names, ages, ethnicities, genders= [], [], [], []

for filename in os.listdir(dataset_folder):
    if filename.endswith('.jpg'):

        parts= filename.split('_')
        if len(parts) < 4:
          print(filename)
          continue

        age= int(parts[0])
        gender= 'Male' if int(parts[1]) == 0 else 'Female'
        ethnicity= ['White', 'Black', 'Asian', 'Indian', 'Others'][int(parts[2])]

        if age > 80:
          continue

        image_names.append(filename)
        ages.append(age)
        ethnicities.append(ethnicity)
        genders.append(gender)

data= {
    'image_name': image_names,
    'age': ages,
    'ethnicity': ethnicities,
    'gender': genders
}
df= pd.DataFrame(data)

csv_filename = os.path.join(drive_path, 'utkface_dataset.csv')
df.to_csv(csv_filename, index=False)

print(f"CSV file '{csv_filename}' created successfully.")
# Out:
# 61_1_20170109150557335.jpg.chip.jpg
# 61_1_20170109142408075.jpg.chip.jpg
# 39_1_20170116174525125.jpg.chip.jpg
# CSV file '/content/drive/MyDrive/Catalist/0_age estimation/utkface_dataset.csv' created successfully.

# %%
df
# Out:
#                                   image_name  age ethnicity  gender
# 0       8_1_3_20170104221828238.jpg.chip.jpg    8    Indian  Female
# 1      46_0_1_20170117185815162.jpg.chip.jpg   46     Black    Male
# 2      45_1_3_20170119200125452.jpg.chip.jpg   45    Indian  Female
# 3      15_0_0_20170104012102240.jpg.chip.jpg   15     White    Male
# 4      27_1_2_20170116173459838.jpg.chip.jpg   27     Asian  Female
# ...                                      ...  ...       ...     ...
# 23160  30_0_0_20170109015231305.jpg.chip.jpg   30     White    Male
# 23161  30_1_4_20170117203009657.jpg.chip.jpg   30    Others  Female
# 23162  24_1_0_20170104022030117.jpg.chip.jpg   24     White  Female
# 23163  52_0_2_20170116192904934.jpg.chip.jpg   52     Asian    Male
# 23164  36_0_3_20170104220656317.jpg.chip.jpg   36    Indian    Male
#
# [23165 rows x 4 columns]

# %% [markdown]
# ## histogram

# %% [markdown]
# ### age

# %%
df['age'].hist(bins= len(df.age.unique()));

# %% [markdown]
# ### gender

# %%
df['gender'].hist(bins= len(df.gender.unique()), rwidth= 0.8);

# %%
df.gender.value_counts()
# Out:
# gender
# Male      12208
# Female    10957
# Name: count, dtype: int64

# %% [markdown]
# ### race

# %%
plt.hist(df.ethnicity);

# %% [markdown]
# ## crosstab

# %% [markdown]
# ### age-race

# %%
pd.crosstab(df.gender, df.ethnicity)
# Out:
# ethnicity  Asian  Black  Indian  Others  White
# gender
# Female      1810   2182    1698     930   4337
# Male        1538   2296    2254     759   5361

# %% [markdown]
# ## boxplot & violinplot

# %% [markdown]
# ### gender

# %%
plt.figure(figsize= (8,4))
plt.boxplot([df.age[df.gender== sex] for sex in df.gender.unique()],
            tick_labels= df.gender.unique(),
            vert= False)
plt.violinplot([df.age[df.gender== sex] for sex in df.gender.unique()],
               vert= False);

# %% [markdown]
# ### race

# %%
plt.figure(figsize= (8,4))
plt.boxplot([df.age[df.ethnicity== race] for race in df.ethnicity.unique()],
            tick_labels= df.ethnicity.unique(),
            vert= False)
plt.violinplot([df.age[df.ethnicity== race] for race in df.ethnicity.unique()],
               vert= False);

# %% [markdown]
# ----------

# %% [markdown]
# # 05_Split data

# %%
df_train_raw, df_test= train_test_split(df, test_size= 0.2,
                                        stratify= df.age, random_state= 42)
df_train, df_valid= train_test_split(df_train_raw, test_size= 0.2,
                                          stratify= df_train_raw.age, random_state= 42)

print(f'train: {df_train.shape}, valid: {df_valid.shape}, test: {df_test.shape}')
# Out:
# train: (14825, 4), valid: (3707, 4), test: (4633, 4)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].hist(df_train.age, bins=len(df_train.age.unique())); axes[0].set_title('Train')
axes[1].hist(df_valid.age, bins=len(df_valid.age.unique())); axes[1].set_title('Validation')
axes[2].hist(df_test.age, bins=len(df_test.age.unique())); axes[2].set_title('Test');

# %%
df_train.to_csv(os.path.join(drive_path,'train_set.csv'), index= False)
df_valid.to_csv(os.path.join(drive_path, 'valid_set.csv'), index= False)
df_test.to_csv(os.path.join(drive_path, 'test_set.csv'), index= False)

print('All CSV files created successfully.')
# Out:
# All CSV files created successfully.

# %% [markdown]
# --------

# %% [markdown]
# # 06_Transform

# %%
train_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(degrees= 15),
    transforms.ColorJitter(brightness= 0.2, contrast= 0.2, saturation= 0.2, hue= 0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean= [0.485, 0.456, 0.406], std= [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean= [0.485, 0.456, 0.406], std= [0.229, 0.224, 0.225]),
])

# %% [markdown]
# ----------

# %% [markdown]
# # 07_Custom dataset

# %%
gender_map= {'Male': 0, 'Female': 1}
race_map= {'White': 0, 'Black': 1, 'Asian': 2, 'Indian': 3, 'Others': 4}
reverse_gender_map= {v: k for k, v in gender_map.items()}
reverse_race_map= {v: k for k, v in race_map.items()}

# %%
class UTK_Dataset(Dataset):
  def __init__(self, root_dir, csv_file, transform):
    self.root_dir, self.csv_file, self.transform= root_dir, csv_file, transform
    self.data= pd.read_csv(self.csv_file)
    self.gender_map= {'Male': 0, 'Female': 1}
    self.race_map= {'White': 0, 'Black': 1, 'Asian': 2, 'Indian': 3, 'Others': 4}

  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    sample= self.data.iloc[idx, :]
    img_name= sample.image_name
    image= Image.open(os.path.join(self.root_dir, img_name))
    image= self.transform(image)

    age= torch.tensor([sample.age], dtype= torch.float32)
    gender= torch.tensor(self.gender_map[sample.gender], dtype= torch.int32)
    race= torch.tensor(self.race_map[sample.ethnicity], dtype= torch.int32)
    return image, age, gender.long(), race.long()

# %%
train_dataset= UTK_Dataset(dataset_folder, os.path.join(drive_path, 'train_set.csv'), train_transform)
valid_dataset= UTK_Dataset(dataset_folder, os.path.join(drive_path, 'valid_set.csv'), test_transform)
test_dataset= UTK_Dataset(dataset_folder, os.path.join(drive_path, 'test_set.csv'), test_transform)

# %%
smp= random.randint(0,len(train_dataset))
img, ag, gndr, rc= train_dataset[smp]
print(img.shape, ag, gndr, rc)
# Out:
# torch.Size([3, 128, 128]) tensor([22.]) tensor(0) tensor(0)

# %% [markdown]
# ----------

# %% [markdown]
# # 08_DataLoader

# %%
train_loader= DataLoader(train_dataset, batch_size= 128, shuffle= True)
valid_loader= DataLoader(valid_dataset, batch_size= 256, shuffle= False)
test_loader= DataLoader(test_dataset, batch_size= 256, shuffle= False)

print("train batch size:",train_loader.batch_size,
     ", num of batch:", len(train_loader))
print("valid batch size:",valid_loader.batch_size,
     ", num of batch:", len(valid_loader))
print("Test batch size:",test_loader.batch_size,
     ", num of batch:", len(test_loader))
# Out:
# train batch size: 128 , num of batch: 116
# valid batch size: 256 , num of batch: 15
# Test batch size: 256 , num of batch: 19

# %%
imgs, ags, gndrs, rcs= next(iter(train_loader));
print(imgs.shape, ags.shape, gndrs.shape, rcs.shape)
# Out:
# torch.Size([128, 3, 128, 128]) torch.Size([128, 1]) torch.Size([128]) torch.Size([128])

# %% [markdown]
# --------

# %% [markdown]
# # 09_Model

# %%
class GR_classifier(nn.Module):
  def __init__(self):
    super().__init__()
    self.Model= models.resnet18(weights= models.ResNet18_Weights.IMAGENET1K_V1)
    self.Model.fc= nn.Identity()
    self.gender_fc= nn.LazyLinear(2)
    self.race_fc= nn.LazyLinear(5)

  def forward(self, x):
    y= self.Model(x)
    y_gender= self.gender_fc(y)
    y_race= self.race_fc(y)
    return y_gender, y_race

# %%
gr_model= GR_classifier()
g, r= gr_model(imgs)
g.shape, r.shape
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 149MB/s]
# (torch.Size([128, 2]), torch.Size([128, 5]))

# %% [markdown]
# -------

# %% [markdown]
# # 10_Configuration

# %%
lr= 0.02
momentum= 0.9
weight_decay= 1e-4
gr_model.to(device)
optimizer= optim.SGD(gr_model.parameters(), lr,
                     momentum= momentum,
                     weight_decay= weight_decay)
g_loss_fn= nn.CrossEntropyLoss()
r_loss_fn= nn.CrossEntropyLoss()
g_metric= tm.Accuracy(task="multiclass", num_classes= 2).to(device)
r_metric= tm.Accuracy(task="multiclass", num_classes= 5).to(device)

# %% [markdown]
# -----------

# %% [markdown]
# # 11_One Epoch fn

# %% [markdown]
# ## train

# %%
def train_one_epoch(model, train_loader, g_loss_fn, r_loss_fn, optimizer, g_metric, r_metric, epoch= None):
  model.train()
  g_loss_train= AverageMeter()
  g_metric.reset()
  r_loss_train= AverageMeter()
  r_metric.reset()

  with tqdm.tqdm(train_loader, unit= 'batch') as tepoch:
    for inputs, _, gender, race in tepoch:
      if epoch:
        tepoch.set_description(f'Epoch {epoch}')

      inputs= inputs.to(device)
      gender, race= gender.to(device), race.to(device)
      output_g, output_r= model(inputs)
      loss_g, loss_r= g_loss_fn(output_g, gender), r_loss_fn(output_r, race)
      loss= loss_g+ loss_r

      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

      g_loss_train.update(loss_g.item(), n=len(gender))
      r_loss_train.update(loss_r.item(), n=len(race))
      g_metric.update(output_g, gender)
      r_metric.update(output_r, race)
      tepoch.set_postfix(metric= f" {100* g_metric.compute().item():.2f}, {100* r_metric.compute().item():.2f}")

  return model, g_loss_train.avg, r_loss_train.avg, g_metric.compute().item(), r_metric.compute().item()

# %% [markdown]
# ## evalution

# %%
def evaluate(model, test_loader, g_loss_fn, r_loss_fn, g_metric, r_metric):
  model.eval()
  g_loss_eval= AverageMeter()
  r_loss_eval= AverageMeter()
  g_metric.reset()
  r_metric.reset()

  with torch.inference_mode():
    for inputs, _, gender, race in test_loader:
      inputs= inputs.to(device)
      gender, race= gender.to(device), race.to(device)
      output_g, output_r= model(inputs)
      loss_g, loss_r= g_loss_fn(output_g, gender), r_loss_fn(output_r, race)

      g_loss_eval.update(loss_g.item(), n= len(gender))
      r_loss_eval.update(loss_r.item(), n= len(race))
      g_metric(output_g, gender)
      r_metric(output_r, race)

  return g_loss_eval.avg, r_loss_eval.avg, g_metric.compute().item(), r_metric.compute().item()

# %% [markdown]
# -------

# %% [markdown]
# # 12_Experiments before the main training

# %% [markdown]
# ## base metrics

# %%
base_loss_g, base_loss_r= [], []
base_metric_g, base_metric_r= [], []
for i in range(10):
  gr_model= GR_classifier().to(device)
  inputs, _, gender, race= next(iter(train_loader))
  inputs= inputs.to(device)
  gender, race= gender.to(device), race.to(device)

  with torch.no_grad():
    output_g, output_r= gr_model(inputs)
    base_loss_g.append(g_loss_fn(output_g, gender))
    base_loss_r.append(r_loss_fn(output_r, race))
    base_metric_g.append(g_metric(output_g, gender))
    base_metric_r.append(r_metric(output_r, race))

print('gender:')
print(f'base loss: {sum(base_loss_g)/len(base_loss_g):.4},')
print(f'base metric: {sum(base_metric_g)/ len(base_metric_g):.4}')
print('race:')
print(f'base loss: {sum(base_loss_r)/len(base_loss_r):.4},')
print(f'base metric: {sum(base_metric_r)/ len(base_metric_r):.4}')
# Out:
# gender:
# base loss: 0.7945,
# base metric: 0.5008
# race:
# base loss: 1.836,
# base metric: 0.2313

# %% [markdown]
# ## overfit on subset of data

# %%
num_epochs= 50
mini_train_size= 1000
mini_batch_size= 50

_, mini_train_dataset= random_split(train_dataset,
                                   (len(train_dataset)- mini_train_size,
                                    mini_train_size))
mini_train_loader= DataLoader(mini_train_dataset, mini_batch_size)
gr_model= GR_classifier().to(device)
optimizer= torch.optim.SGD(gr_model.parameters(), lr= 1e-2, momentum= 0.9)

for epoch in range(num_epochs):
  age_model, _, _, _, _ = train_one_epoch(gr_model, mini_train_loader, g_loss_fn, r_loss_fn,
                                    optimizer, g_metric, r_metric, epoch)
# Out:
# 100%|██████████| 20/20 [00:06<00:00,  3.12batch/s, metric=71.40, 43.30]
# Epoch 1: 100%|██████████| 20/20 [00:06<00:00,  3.06batch/s, metric=77.60, 55.10]
# Epoch 2: 100%|██████████| 20/20 [00:06<00:00,  3.20batch/s, metric=84.80, 61.80]
# Epoch 3: 100%|██████████| 20/20 [00:05<00:00,  3.67batch/s, metric=87.60, 70.90]
# Epoch 4: 100%|██████████| 20/20 [00:05<00:00,  3.63batch/s, metric=89.70, 76.30]
# Epoch 5: 100%|██████████| 20/20 [00:06<00:00,  3.27batch/s, metric=92.30, 81.40]
# Epoch 6: 100%|██████████| 20/20 [00:05<00:00,  3.62batch/s, metric=92.90, 82.10]
# Epoch 7: 100%|██████████| 20/20 [00:06<00:00,  3.03batch/s, metric=93.40, 82.30]
# Epoch 8: 100%|██████████| 20/20 [00:05<00:00,  3.57batch/s, metric=95.10, 85.20]
# Epoch 9: 100%|██████████| 20/20 [00:06<00:00,  3.11batch/s, metric=95.10, 84.00]
# Epoch 10: 100%|██████████| 20/20 [00:05<00:00,  3.48batch/s, metric=94.10, 86.60]
# Epoch 11: 100%|██████████| 20/20 [00:05<00:00,  3.51batch/s, metric=94.00, 88.30]
# Epoch 12: 100%|██████████| 20/20 [00:06<00:00,  3.19batch/s, metric=95.20, 89.60]
# Epoch 13: 100%|██████████| 20/20 [00:05<00:00,  3.62batch/s, metric=94.80, 88.70]
# Epoch 14: 100%|██████████| 20/20 [00:06<00:00,  3.03batch/s, metric=94.40, 90.60]
# Epoch 15: 100%|██████████| 20/20 [00:05<00:00,  3.60batch/s, metric=95.30, 89.60]
# Epoch 16: 100%|██████████| 20/20 [00:06<00:00,  3.02batch/s, metric=95.90, 91.80]
# Epoch 17: 100%|██████████| 20/20 [00:05<00:00,  3.50batch/s, metric=96.20, 95.50]
# Epoch 18: 100%|██████████| 20/20 [00:05<00:00,  3.40batch/s, metric=96.80, 96.50]
# Epoch 19: 100%|██████████| 20/20 [00:06<00:00,  3.20batch/s, metric=96.40, 97.00]
# Epoch 20: 100%|██████████| 20/20 [00:05<00:00,  3.58batch/s, metric=96.80, 97.70]
# Epoch 21: 100%|██████████| 20/20 [00:06<00:00,  3.13batch/s, metric=98.90, 97.90]
# Epoch 22: 100%|██████████| 20/20 [00:05<00:00,  3.63batch/s, metric=99.50, 98.10]
# Epoch 23: 100%|██████████| 20/20 [00:06<00:00,  3.10batch/s, metric=99.80, 99.00]
# Epoch 24: 100%|██████████| 20/20 [00:05<00:00,  3.60batch/s, metric=99.60, 98.70]
# Epoch 25: 100%|██████████| 20/20 [00:06<00:00,  3.32batch/s, metric=99.30, 99.20]
# Epoch 26: 100%|██████████| 20/20 [00:06<00:00,  3.13batch/s, metric=99.70, 99.50]
# Epoch 27: 100%|██████████| 20/20 [00:05<00:00,  3.40batch/s, metric=99.80, 99.60]
# Epoch 28: 100%|██████████| 20/20 [00:06<00:00,  2.94batch/s, metric=99.90, 99.60]
# Epoch 29: 100%|██████████| 20/20 [00:05<00:00,  3.62batch/s, metric=100.00, 99.50]
# Epoch 30: 100%|██████████| 20/20 [00:06<00:00,  3.02batch/s, metric=99.90, 99.70]
# Epoch 31: 100%|██████████| 20/20 [00:05<00:00,  3.55batch/s, metric=99.70, 99.60]
# Epoch 32: 100%|██████████| 20/20 [00:06<00:00,  3.14batch/s, metric=99.70, 99.40]
# Epoch 33: 100%|██████████| 20/20 [00:05<00:00,  3.54batch/s, metric=99.80, 99.10]
# Epoch 34: 100%|██████████| 20/20 [00:05<00:00,  3.58batch/s, metric=99.70, 99.50]
# Epoch 35: 100%|██████████| 20/20 [00:06<00:00,  3.20batch/s, metric=99.70, 99.40]
# Epoch 36: 100%|██████████| 20/20 [00:05<00:00,  3.63batch/s, metric=99.90, 99.70]
# Epoch 37: 100%|██████████| 20/20 [00:06<00:00,  3.11batch/s, metric=99.70, 99.80]
# Epoch 38: 100%|██████████| 20/20 [00:05<00:00,  3.68batch/s, metric=99.60, 100.00]
# Epoch 39: 100%|██████████| 20/20 [00:06<00:00,  3.28batch/s, metric=99.90, 99.80]
# Epoch 40: 100%|██████████| 20/20 [00:06<00:00,  2.96batch/s, metric=99.80, 100.00]
# Epoch 41: 100%|██████████| 20/20 [00:05<00:00,  3.41batch/s, metric=100.00, 99.90]
# Epoch 42: 100%|██████████| 20/20 [00:06<00:00,  3.28batch/s, metric=99.90, 99.80]
# Epoch 43: 100%|██████████| 20/20 [00:05<00:00,  3.71batch/s, metric=100.00, 99.90]
# Epoch 44: 100%|██████████| 20/20 [00:06<00:00,  3.13batch/s, metric=100.00, 99.70]
# Epoch 45: 100%|██████████| 20/20 [00:05<00:00,  3.74batch/s, metric=100.00, 99.80]
# Epoch 46: 100%|██████████| 20/20 [00:06<00:00,  3.29batch/s, metric=100.00, 99.70]
# Epoch 47: 100%|██████████| 20/20 [00:05<00:00,  3.52batch/s, metric=100.00, 100.00]
# Epoch 48: 100%|██████████| 20/20 [00:05<00:00,  3.60batch/s, metric=100.00, 100.00]
# Epoch 49: 100%|██████████| 20/20 [00:06<00:00,  3.15batch/s, metric=100.00, 99.90]

# %% [markdown]
# ## grid search

# %%
num_epochs= 3
# 0.1,
for lr in [0.01, 0.001, 0.0001]:
  print(f'LR={lr}')
  gr_model= GR_classifier().to(device)
  optimizer= optim.SGD(gr_model.parameters(), lr= lr,
                       weight_decay= 1e-4, momentum= 0.9)

  for epoch in range(num_epochs):
    gr_model, _, _, _, _= train_one_epoch(gr_model, train_loader, g_loss_fn, r_loss_fn,
                                          optimizer, g_metric, r_metric, epoch)
  print()
# Out:
# LR=0.01
# 100%|██████████| 116/116 [01:13<00:00,  1.58batch/s, metric=84.14, 66.88]
# Epoch 1: 100%|██████████| 116/116 [01:14<00:00,  1.56batch/s, metric=89.43, 78.33]
# Epoch 2: 100%|██████████| 116/116 [01:14<00:00,  1.55batch/s, metric=90.81, 81.20]
# LR=0.001
# 100%|██████████| 116/116 [01:12<00:00,  1.59batch/s, metric=77.32, 54.16]
# Epoch 1: 100%|██████████| 116/116 [01:13<00:00,  1.57batch/s, metric=86.50, 68.81]
# Epoch 2: 100%|██████████| 116/116 [01:13<00:00,  1.58batch/s, metric=88.46, 74.80]
# LR=0.0001
# 100%|██████████| 116/116 [01:14<00:00,  1.56batch/s, metric=63.24, 40.34]
# Epoch 1: 100%|██████████| 116/116 [01:14<00:00,  1.56batch/s, metric=74.61, 50.02]
# Epoch 2: 100%|██████████| 116/116 [01:12<00:00,  1.59batch/s, metric=78.25, 54.47]

# %%
num_epochs= 3

for lr in [0.03, 0.01, 0.008]:
  for wd in [1e-4, 0.]:
    print(f'LR={lr}, WD={wd}')
    gr_model= GR_classifier().to(device)
    optimizer= optim.SGD(gr_model.parameters(), lr= lr, weight_decay= wd, momentum= 0.9)

    for epoch in range(num_epochs):
      gr_model, _, _, _, _= train_one_epoch(gr_model, train_loader, g_loss_fn, r_loss_fn,
                                            optimizer, g_metric, r_metric, epoch)
    print()
# Out:
# LR=0.03, WD=0.0001
# 100%|██████████| 116/116 [01:12<00:00,  1.59batch/s, metric=79.87, 60.29]
# Epoch 1: 100%|██████████| 116/116 [01:15<00:00,  1.55batch/s, metric=86.28, 70.15]
# Epoch 2: 100%|██████████| 116/116 [01:13<00:00,  1.59batch/s, metric=84.21, 67.97]
# LR=0.03, WD=0.0
# 100%|██████████| 116/116 [01:13<00:00,  1.58batch/s, metric=77.98, 57.90]
# Epoch 1: 100%|██████████| 116/116 [01:13<00:00,  1.58batch/s, metric=88.72, 75.34]
# Epoch 2: 100%|██████████| 116/116 [01:13<00:00,  1.57batch/s, metric=89.85, 78.75]
# LR=0.01, WD=0.0001
# 100%|██████████| 116/116 [01:13<00:00,  1.58batch/s, metric=82.50, 67.04]
# Epoch 1: 100%|██████████| 116/116 [01:13<00:00,  1.59batch/s, metric=89.32, 78.95]
# Epoch 2: 100%|██████████| 116/116 [01:13<00:00,  1.57batch/s, metric=91.46, 81.94]
# LR=0.01, WD=0.0
# 100%|██████████| 116/116 [01:13<00:00,  1.57batch/s, metric=83.15, 65.94]
# Epoch 1: 100%|██████████| 116/116 [01:13<00:00,  1.58batch/s, metric=89.88, 79.22]
# Epoch 2: 100%|██████████| 116/116 [01:14<00:00,  1.55batch/s, metric=91.53, 81.52]
# LR=0.008, WD=0.0001
# 100%|██████████| 116/116 [01:13<00:00,  1.58batch/s, metric=83.50, 67.14]
# Epoch 1: 100%|██████████| 116/116 [01:13<00:00,  1.58batch/s, metric=89.65, 78.34]
# Epoch 2: 100%|██████████| 116/116 [01:13<00:00,  1.58batch/s, metric=91.97, 82.11]
# LR=0.008, WD=0.0
# 100%|██████████| 116/116 [01:12<00:00,  1.60batch/s, metric=83.40, 66.63]
# Epoch 1: 100%|██████████| 116/116 [01:14<00:00,  1.55batch/s, metric=89.90, 78.33]
# Epoch 2: 100%|██████████| 116/116 [01:12<00:00,  1.59batch/s, metric=91.12, 81.44]

# %% [markdown]
# ----------

# %% [markdown]
# # 13_Training

# %%
g_loss_train_hist, r_loss_train_hist= [], []
g_loss_valid_hist, r_loss_valid_hist= [], []

g_metric_train_hist, r_metric_train_hist= [], []
g_metric_valid_hist, r_metric_valid_hist= [], []

best_loss_valid_g, best_loss_valid_r= torch.inf, torch.inf
epoch_counter= 0

gr_model= GR_classifier().to(device)

# %%
lr= 0.01
wd= 1e-4
optimizer= optim.SGD(gr_model.parameters(), lr= lr,
                     weight_decay= wd, momentum= 0.9)

# %%
num_epochs= 5

for epoch in range(num_epochs):
  gr_model, _, _, g_metric_train, r_metric_train= train_one_epoch(gr_model, train_loader,
                                                       g_loss_fn, r_loss_fn, optimizer,
                                                       g_metric, r_metric, epoch)
  g_loss_valid, r_loss_valid, g_metric_valid, r_metric_valid= evaluate(gr_model, valid_loader,
                                                                       g_loss_fn, r_loss_fn,
                                                                       g_metric, r_metric)


  g_metric_train_hist.append(g_metric_train), r_metric_train_hist.append(r_metric_train)
  g_metric_valid_hist.append(g_metric_valid), r_metric_valid_hist.append(r_metric_valid)

  if (g_loss_valid < best_loss_valid_g) or (r_loss_valid < best_loss_valid_r):
    torch.save(gr_model, os.path.join(drive_path, 'gr_model.pt'))
    if (g_loss_valid < best_loss_valid_g):
      best_loss_valid_g= g_loss_valid
    if (r_loss_valid < best_loss_valid_r):
      best_loss_valid_r= r_loss_valid
    print('Model Saved!')

  print("Valid")
  print(f'Metric: Gender= {100*g_metric_valid:.4}, Race= {100*r_metric_valid:.4}')
  print(f'Loss: Gender= {100*g_loss_valid:.4}, Race= {100*r_loss_valid:.4}')
  print()

  epoch_counter += 1
# Out:
# 100%|██████████| 116/116 [01:12<00:00,  1.59batch/s, metric=83.25, 66.49]
# Model Saved!
# Valid
# Metric: Gender= 88.27, Race= 76.8
# Loss: Gender= 26.83, Race= 71.09
# Epoch 1: 100%|██████████| 116/116 [01:14<00:00,  1.55batch/s, metric=89.27, 78.38]
# Model Saved!
# Valid
# Metric: Gender= 90.15, Race= 80.52
# Loss: Gender= 24.23, Race= 59.2
# Epoch 2: 100%|██████████| 116/116 [01:12<00:00,  1.61batch/s, metric=90.97, 81.23]
# Model Saved!
# Valid
# Metric: Gender= 88.72, Race= 79.85
# Loss: Gender= 31.58, Race= 59.18
# Epoch 3: 100%|██████████| 116/116 [01:11<00:00,  1.62batch/s, metric=91.55, 82.86]
# Model Saved!
# Valid
# Metric: Gender= 92.45, Race= 79.61
# Loss: Gender= 19.26, Race= 61.51
# Epoch 4: 100%|██████████| 116/116 [01:13<00:00,  1.59batch/s, metric=92.79, 84.36]
# Model Saved!
# Valid
# Metric: Gender= 92.2, Race= 81.79
# Loss: Gender= 19.95, Race= 54.99

# %% [markdown]
# -----

# %% [markdown]
# # 14_Learning curve

# %% [markdown]
# ## loss

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(len(g_loss_train_hist)), g_loss_train_hist, 'k-', label='gender')
plt.plot(range(len(r_loss_valid_hist)), r_loss_valid_hist, 'b-', label='race')

plt.xlabel('Epoch')
plt.ylabel('loss')
plt.grid(True)
plt.legend()

# %% [markdown]
# ## metric

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(len(g_metric_valid_hist)), g_metric_valid_hist, 'k-', label='gender')
plt.plot(range(len(r_metric_valid_hist)), r_metric_valid_hist, 'b-', label='race')

plt.xlabel('Epoch')
plt.ylabel('metric')
plt.grid(True)
plt.legend()

# %% [markdown]
# ----------

# %% [markdown]
# # 15_Test

# %%
model_path= os.path.join(drive_path, 'gr_model.pt')
gr_model= torch.load(model_path)
gr_model.eval()

_, _, g_metric_train, r_metric_train= evaluate(gr_model, train_loader,
                                               g_loss_fn, r_loss_fn, g_metric, r_metric)
_, _, g_metric_valid, r_metric_valid= evaluate(gr_model, valid_loader,
                                               g_loss_fn, r_loss_fn, g_metric, r_metric)
_, _, g_metric_test, r_metric_test= evaluate(gr_model, test_loader,
                                             g_loss_fn, r_loss_fn, g_metric, r_metric)

print(f'train: {100* g_metric_train:.2f}, {100* r_metric_train:.2f}')
print(f'valid: {100* g_metric_valid:.2f}, {100* r_metric_valid:.2f}')
print(f'Test: {100* g_metric_test:.2f}, {100* r_metric_test:.2f}')
# Out:
# <ipython-input-45-37eda62ff6bc>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   gr_model= torch.load(model_path)
# train: 94.34, 86.35
# valid: 92.20, 81.79
# Test: 92.23, 81.48

# %%
model_path= os.path.join(drive_path, 'gr_model.pt')
gr_model= torch.load(model_path)
gr_model.eval()

df= pd.read_csv(os.path.join(drive_path, 'test_set.csv'))
test_image_name= df.iloc[random.randint(0, df.shape[0])].image_name
test_image_path= os.path.join(dataset_folder, test_image_name)
img= Image.open(test_image_path).convert('RGB')
img_tensor= test_transform(img).unsqueeze(0)
with torch.inference_mode():
  g_preds, r_preds= gr_model(img_tensor.to(device))
real_g, real_r= test_image_name.split('_')[1],test_image_name.split('_')[2]
print("Gender")
print(f"Real: {reverse_gender_map[int(real_g)]}, Predicted: {reverse_gender_map[int(torch.argmax(g_preds))]}")
print("Race")
print(f"Real: {reverse_race_map[int(real_r)]}, Predicted: {reverse_race_map[int(torch.argmax(r_preds))]}")
img
# Out:
# <ipython-input-46-4199b21be533>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   gr_model= torch.load(model_path)
# Gender
# Real: Male, Predicted: Male
# Race
# Real: Asian, Predicted: Asian
# <PIL.Image.Image image mode=RGB size=200x200>

# %% [markdown]
# -------

# %% [markdown]
# # 16_Inference

# %%
# !pip install face-recognition
import face_recognition
# Out:
# Collecting face-recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting face-recognition-models>=0.3.0 (from face-recognition)
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.11/dist-packages (from face-recognition) (8.1.8)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.11/dist-packages (from face-recognition) (19.24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from face-recognition) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from face-recognition) (11.1.0)
# Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566162 sha256=48d346d05d3ccacc7b052f922b38735dce078127eb6815f03f0ed64744b946cb
#   Stored in directory: /root/.cache/pip/wheels/04/52/ec/9355da79c29f160b038a20c784db2803c2f9fa2c8a462c176a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
def inference(image_path, transform, model, face_detection= False):
  if face_detection:
    img= face_recognition.load_image_file(image_path)
    top, right, bottom, left= face_recognition.face_locations(img)[0]
    img_crop= Image.fromarray(img[top:bottom, left:right])
  else:
    img_crop= Image.open(image_path).convert('RGB')

  img_tensor= transform(img_crop).unsqueeze(0)
  with torch.inference_mode():
    g_preds, r_preds= model(img_tensor.to(device))

  return g_preds, r_preds, img_crop

# %%
g_preds, r_preds, img= inference(os.path.join(drive_path, 'test_image.jpeg'),
          test_transform, gr_model, face_detection= True)

print(f'{g_preds}, {r_preds}')
img
# Out:
# tensor([[ 4.1659, -5.3385]], device='cuda:0'), tensor([[ 5.2908, -3.5872, -4.2837,  0.0440,  2.5330]], device='cuda:0')
# <PIL.Image.Image image mode=RGB size=154x155>

# %% [markdown]
# --------

# %% [markdown]
# # 17_Experiments

# %%
age_model= torch.load(os.path.join(drive_path, 'gr_model.pt'), map_location= device)
age_model.eval();
# Out:
# <ipython-input-52-2fb42cb19594>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   age_model= torch.load(os.path.join(drive_path, 'gr_model.pt'), map_location= device)

# %% [markdown]
# ## analyze the model's sensitivity

# %%
img= Image.open(os.path.join(drive_path, 'test_image_1.jpeg')).convert('RGB')
img_tensor= test_transform(img).unsqueeze(0)

with torch.inference_mode():
  gender_pr, race_pr= gr_model(img_tensor.to(device))

print(f"{reverse_gender_map[int(torch.argmax(gender_pr))]}, {reverse_race_map[int(torch.argmax(race_pr))]}")
img
# Out:
# Male, White
# <PIL.Image.Image image mode=RGB size=184x200>

# %%
img= Image.open(os.path.join(drive_path, 'test_image_2.jpeg')).convert('RGB')
img_tensor= test_transform(img).unsqueeze(0)

with torch.inference_mode():
  gender_pr, race_pr= gr_model(img_tensor.to(device))

print(f"{reverse_gender_map[int(torch.argmax(gender_pr))]}, {reverse_race_map[int(torch.argmax(race_pr))]}")
img
# Out:
# Male, White
# <PIL.Image.Image image mode=RGB size=184x261>

# %%
img= Image.open(os.path.join(drive_path, 'test_image.jpeg')).convert('RGB')
img_tensor= test_transform(img).unsqueeze(0)

with torch.inference_mode():
  gender_pr, race_pr= gr_model(img_tensor.to(device))

print(f"{reverse_gender_map[int(torch.argmax(gender_pr))]}, {reverse_race_map[int(torch.argmax(race_pr))]}")
img
# Out:
# Male, Black
# <PIL.Image.Image image mode=RGB size=540x360>

# %% [markdown]
# ## heatmap
